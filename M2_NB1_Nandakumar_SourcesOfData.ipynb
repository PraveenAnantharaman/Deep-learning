# %% [markdown]
# <div align="right">Python 2.7 Jupyter Notebook</div>

# %% [markdown]
# # Sources of data

# %% [markdown]
# ### Your completion of the Notebook exercises will be graded based on your ability to:
#
# > **Apply**: Are you able to execute code, using the supplied examples, that perform the required functionality on supplied or generated data sets?
#
# > **Evaluate**: Are you able to interpret the results and justify your interpretation based on the observed data?
#
# > **Create**: Your ability to produce notebooks that serve as computational record of a session that can be used to share your insights with others?

# %% [markdown]
# # Notebook introduction
#
# Data collection is expensive and time consuming, as Arek Stopczynski alluded to in the video 2 resource on the learning path.
# In some cases you will be lucky enough to have existing datasets available to support your analysis. You may have datasets from previous analyses, access to providers, or curated datasets from your organization. In many cases, however, you will not have access to the data that you require to support your analysis, and you will have to find alternate mechanisms.
# The data quality requirements will differ based on the problem that you are trying to solve. Taking the hypothetical case of geocoding a location that was introduced in Module 1, the accuracy of the geocoded location does not need to be exact when you are simply trying to plot the locations of students on a map. Geocoding a location for an automated vehicle to turn off the highway, on the other hand, has an entirely different accuracy requirement.
#
# > **Note**:
#
# > Those of you who work in large organizations may be privileged enough to have company data governance and data quality initiatives. These efforts and teams can generally add significant value both in terms of supplying company-standard curated data, and making you aware of the internal policies that need to be adhered to.
#
# As a data analyst or data scientist, it is important to be aware of the implications of your decisions. You need to choose the appropriate set of tools and methods to deal with sourcing and supplying data.
#
# Technology has matured in recent years, and allowed access to a host of sources of data that can be used in our analyses. In many cases you can access free resources, or obtain data that has been curated, is at a lower latency, or comes with a service-level agreement at a cost. Some governments have even made datasets publicly available.
#
# You have been introduced to [OpenPDS](http://openpds.media.mit.edu/) in the video content where the focus shifts from supplying raw data - where the provider needs to apply security principles before sharing datasets - to supplying answers rather than data. OpenPDS allows users to collect, store, and control access to their data, while also allowing them to protect their privacy. In this way, users still have ownership of their data, as defined in the new deal on data.
#
# This notebook will demonstrate another example of sourcing external data to enrich your analyses. The Python ecosystem contains a rich set of tools and libraries that can help you to exploit the available resources.
#
# This course will not go into detail regarding the various options to source and interact with social data from sources such as Twitter, LinkedIn, Facebook, and Google Plus. However, you should be able to find libraries that will assist you in sourcing and manipulating these sources of data.
#
# Twitter data is a good example as, depending on the options selected by the twitter user, every tweet contains not just the message or content that most users are aware of. It also contains a view on the network of the person, home location, location from which the message was sent, and a number of other features that can be very useful when studying networks around a topic of interest. Professor Pentland pointed out the difference in what you share with the world (how you want to be seen) compared to what you actually do and believe (what you commit to). Ensure you keep these concepts in mind when you start exploring the additional sources of data. Those who are interested in the topic can start to explore the options by visiting the [twitter library on pypi](https://pypi.python.org/pypi/twitter).
#
# Start with the five Rs introduced in module 1, and consider the following questions:
# - How accurate does my dataset need to be?
# - How often should the dataset be updated?
# - What happens if the data provider is no longer available?
# - Do I need to adhere to any organizational standards to ensure consistent reporting or integration with other applications?
# - Are there any implications to getting the values wrong?
#
# You may need to start with “untrusted” data sources as a means of validating that your analysis can be executed. Once this is done, you can replace the untrusted components with trusted and curated datasets as your analysis matures.
#
# > **Note**:
#
# > It is strongly recommended that you save a checkpoint after applying significant changes or completing exercises. This allows you to return the notebook to a previous state should you wish to do so. On the Jupyter menu, select "File", then "Save and Checkpoint" from the dropdown menu that appears.

# %% [markdown]
# #### Load libraries and set options

# %%
import pandas as pd
from pandas_datareader import data, wb
import numpy as np
import matplotlib
import folium
import geocoder
#import urllib2
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 8)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 1. Source additional data from public sources
# ## 1.1 World-bank
#
# This example will demonstrate how to source data from an external source to enrich your existing analyses. You will need to combine the data sources and add additional features to the example of student locations plotted on the world map in Module 1, Notebook 3.
#
# The specific indicator chosen has little relevance other than to demonstrate the process that you will typically follow in completing your projects. Population counts, from an untrusted source, is added to our map and we use scaling factors combined with the number of students and population size of the country to demonstrate adding external data with minimal effort.
#
# You can read more about the library that is utilized in this notebook [here](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html#world-bank).

# %%
# Load the grouped_geocoded dataset from Module 1.
df1 = pd.read_csv('data/grouped_geocoded.csv',index_col=[0])

# Prepare the student location dataset for use in this example.
# We use the geometrical center by obtaining the mean location for all observed coordinates per country.
df2 = df1.groupby('country').agg({'student_count': [np.sum], 'lat': [np.mean], 
                                  'long': [np.mean]}).reset_index()
# Reset the index.
df3 = df2.reset_index(level=1, drop=True)

# Get the external dataset from worldbank
#  We have selected indicator, "SP.POP.TOTL"
df4 = wb.download(
                    # Specify indicator to retrieve
                    indicator='SP.POP.TOTL',
                    country=['all'],
                    # Start Year
                    start='2008',
                    # End Year
                    end=2016
                )

# The dataset contains entries for multiple years.
#    We just want the last entry and create a separate object containing the list of maximum values
df5 = df4.reset_index()
idx = df5.groupby(['country'])['SP.POP.TOTL'].transform(max) == df4['SP.POP.TOTL']

# Create a new dataframe where entries corresponds to maximum year indexes in previous list.
df6 = df5[idx]

# Combine the student and population datasets.
df7 = pd.merge(df3, df6, on='country', how='left')

# Rename the columns or our merged dataset.
df8 = df7.rename(index=str, columns={('lat', 'mean'): "lat_mean", 
                                ('long', 'mean'): "long_mean", 
                                ('SP.POP.TOTL'): "PopulationTotal_Latest_WB",
                                ('student_count', 'sum'): "student_count"}
           )
# Out:
# /home/ubuntu/.local/lib/python2.7/site-packages/pandas/tools/merge.py:205: UserWarning: merging between different levels can give an unintended result (2 levels on the left, 1 on the right)
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# > **Note**:
#
# > The cell above will complete with a warning message the first time that you execute the cell. You can ignore the warning and continue to the next cell to plot the indicator added.
#
# > The visualization below does not have any meaning. The scaling factors selected is used to demonstrate the difference in population sizes and number of students on this course per country.

# %%
# Plot the combined dataset

# Set map center and zoom level
mapc = [0, 30]
zoom = 2

# Create map object.
map_osm = folium.Map(location=mapc,
                   tiles='Stamen Toner',
                    zoom_start=zoom)

# Plot each of the locations that we geocoded.
for j in range(len(df8)):
    # Plot a blue circle marker for country population.
    folium.CircleMarker([df8.lat_mean[j], df8.long_mean[j]],
                    radius=df8.PopulationTotal_Latest_WB[j]/500,
                    popup='Population',
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm)
    # Plot a red circle marker for students per country.
    folium.CircleMarker([df8.lat_mean[j], df8.long_mean[j]],
                    radius=df8.student_count[j]*10000,
                    popup='Students',
                    color='red',
                    fill_color='red',
                   ).add_to(map_osm)
# Show the map.
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# <br>
# <div class="alert alert-info">
# <b>Exercise 1 Start.</b>
# </div>
#
# ### Instructions
#
# > Copy the code from the previous two cells into the cells below. After you've reviewed the available indicators in the [worldbank](http://data.worldbank.org/indicator) dataset, replace the population indicator with an indicator of your choice. Add comments (lines starting with #) giving a brief description of your view on the observed results. Make sure to provide the tutor with a clear description of why you selected the indicator, what your expectation was when you started and what you think the results may indicate.
#
# > **Note**: Advanced users are welcome to source data from alternate data sources or manually upload files to be utilized to their virtual analysis environment.

# %%
# Your data preparation code
df9 = wb.download(
                    # Specify indicator to retrieve
                    indicator='NY.GDP.PCAP.KD', #GDP of each country
                    country=['all'],
                    # Start Year
                    start='2008',
                    # End Year
                    end=2016
                )
# The dataset contains entries for multiple years.
#    We just want the last entry and create a separate object containing the list of maximum values
df10 = df9.reset_index()
idx = df10.groupby(['country'])['NY.GDP.PCAP.KD'].transform(max) == df9['NY.GDP.PCAP.KD']

# Create a new dataframe where entries corresponds to maximum year indexes in previous list.
df11 = df10[idx]

# Combine the student and population datasets.
df12 = pd.merge(df3, df11, on='country', how='left')

# Rename the columns or our merged dataset.
df13 = df12.rename(index=str, columns={('lat', 'mean'): "lat_mean", 
                                ('long', 'mean'): "long_mean", 
                                ('NY.GDP.PCAP.KD'): "GDP_Worldbank",
                                ('student_count', 'sum'): "student_count"}
           )

# %%
wb.search('population')
# Out:
#                                    id  \
# 24         1.1_ACCESS.ELECTRICITY.TOT
# 39       1.2_ACCESS.ELECTRICITY.RURAL
# 40       1.3_ACCESS.ELECTRICITY.URBAN
# 118       2.1_ACCESS.NONSOLIDFUEL.TOT
# 121     2.2_ACCESS.NONSOLIDFUEL.RURAL
# 123     2.3_ACCESS.NONSOLIDFUEL.URBAN
# 161                 3.11.01.01.popcen
# 1134              BAR.NOED.1519.FE.ZS
# 1135                 BAR.NOED.1519.ZS
# 1136              BAR.NOED.15UP.FE.ZS
# 1137                 BAR.NOED.15UP.ZS
# 1138              BAR.NOED.2024.FE.ZS
# 1139                 BAR.NOED.2024.ZS
# 1140              BAR.NOED.2529.FE.ZS
# 1141                 BAR.NOED.2529.ZS
# 1142              BAR.NOED.25UP.FE.ZS
# 1143                 BAR.NOED.25UP.ZS
# 1144              BAR.NOED.3034.FE.ZS
# 1145                 BAR.NOED.3034.ZS
# 1146              BAR.NOED.3539.FE.ZS
# 1147                 BAR.NOED.3539.ZS
# 1148              BAR.NOED.4044.FE.ZS
# 1149                 BAR.NOED.4044.ZS
# 1150              BAR.NOED.4549.FE.ZS
# 1151                 BAR.NOED.4549.ZS
# 1152              BAR.NOED.5054.FE.ZS
# 1153                 BAR.NOED.5054.ZS
# 1154              BAR.NOED.5559.FE.ZS
# 1155                 BAR.NOED.5559.ZS
# 1156              BAR.NOED.6064.FE.ZS
# ...                               ...
# 16232   per_saoth.overlap_ep_preT_tot
# 16233        per_saoth.overlap_ep_tot
# 16234  per_saoth.overlap_pop_preT_tot
# 16235       per_saoth.overlap_pop_rur
# 16236       per_saoth.overlap_pop_tot
# 16237       per_saoth.overlap_pop_urb
# 16238   per_saoth.overlap_q1_preT_tot
# 16239        per_saoth.overlap_q1_rur
# 16240        per_saoth.overlap_q1_tot
# 16241        per_saoth.overlap_q1_urb
# 16826    per_silm.overlap_ep_preT_tot
# 16827         per_silm.overlap_ep_tot
# 16828   per_silm.overlap_pop_preT_tot
# 16829        per_silm.overlap_pop_rur
# 16830        per_silm.overlap_pop_tot
# 16831        per_silm.overlap_pop_urb
# 16832    per_silm.overlap_q1_preT_tot
# 16833         per_silm.overlap_q1_rur
# 16834         per_silm.overlap_q1_tot
# 16835         per_silm.overlap_q1_urb
# 16836   per_sionl.overlap_ep_preT_tot
# 16837        per_sionl.overlap_ep_tot
# 16838  per_sionl.overlap_pop_preT_tot
# 16839       per_sionl.overlap_pop_rur
# 16840       per_sionl.overlap_pop_tot
# 16841       per_sionl.overlap_pop_urb
# 16842   per_sionl.overlap_q1_preT_tot
# 16843        per_sionl.overlap_q1_rur
# 16844        per_sionl.overlap_q1_tot
# 16845        per_sionl.overlap_q1_urb
#
#                                                     name  \
# 24         Access to electricity (% of total population)
# 39         Access to electricity (% of rural population)
# 40         Access to electricity (% of urban population)
# 118     Access to Non-Solid Fuel (% of total population)
# 121     Access to Non-Solid Fuel (% of rural population)
# 123     Access to Non-Solid Fuel (% of urban population)
# 161                                    Population census
# 1134   Barro-Lee: Percentage of female population age...
# 1135   Barro-Lee: Percentage of population age 15-19 ...
# 1136   Barro-Lee: Percentage of female population age...
# 1137   Barro-Lee: Percentage of population age 15+ wi...
# 1138   Barro-Lee: Percentage of female population age...
# 1139   Barro-Lee: Percentage of population age 20-24 ...
# 1140   Barro-Lee: Percentage of female population age...
# 1141   Barro-Lee: Percentage of population age 25-29 ...
# 1142   Barro-Lee: Percentage of female population age...
# 1143   Barro-Lee: Percentage of population age 25+ wi...
# 1144   Barro-Lee: Percentage of female population age...
# 1145   Barro-Lee: Percentage of population age 30-34 ...
# 1146   Barro-Lee: Percentage of female population age...
# 1147   Barro-Lee: Percentage of population age 35-39 ...
# 1148   Barro-Lee: Percentage of female population age...
# 1149   Barro-Lee: Percentage of population age 40-44 ...
# 1150   Barro-Lee: Percentage of female population age...
# 1151   Barro-Lee: Percentage of population age 45-49 ...
# 1152   Barro-Lee: Percentage of female population age...
# 1153   Barro-Lee: Percentage of population age 50-54 ...
# 1154   Barro-Lee: Percentage of female population age...
# 1155   Barro-Lee: Percentage of population age 55-59 ...
# 1156   Barro-Lee: Percentage of female population age...
# ...                                                  ...
# 16232  Population in extreme poor (<$1.25 a day) rece...
# 16233  Population in extreme poor (<$1.25 a day) rece...
# 16234  Population receiving Social Assistance and Oth...
# 16235  Population receiving Social Assistance and Oth...
# 16236  Population receiving Social Assistance and Oth...
# 16237  Population receiving Social Assistance and Oth...
# 16238  Population in the poorest quintile receiving S...
# 16239  Population in the poorest quintile receiving S...
# 16240  Population in the poorest quintile receiving S...
# 16241  Population in the poorest quintile receiving S...
# 16826  Population in extreme poor (<$1.25 a day) rece...
# 16827  Population in extreme poor (<$1.25 a day) rece...
# 16828  Population receiving All Social Insurance and ...
# 16829  Population receiving All Social Insurance and ...
# 16830  Population receiving All Social Insurance and ...
# 16831  Population receiving All Social Insurance and ...
# 16832  Population in the poorest quintile receiving A...
# 16833  Population in the poorest quintile receiving A...
# 16834  Population in the poorest quintile receiving A...
# 16835  Population in the poorest quintile receiving A...
# 16836  Population in extreme poor (<$1.25 a day) only...
# 16837  Population in extreme poor (<$1.25 a day) only...
# 16838  Population only receiving All Social Insurance...
# 16839  Population only receiving All Social Insurance...
# 16840  Population only receiving All Social Insurance...
# 16841  Population only receiving All Social Insurance...
# 16842  Population in the poorest quintile only receiv...
# 16843  Population in the poorest quintile only receiv...
# 16844  Population in the poorest quintile only receiv...
# 16845  Population in the poorest quintile only receiv...
#
#                                 source  \
# 24          Sustainable Energy for All
# 39          Sustainable Energy for All
# 40          Sustainable Energy for All
# 118         Sustainable Energy for All
# 121         Sustainable Energy for All
# 123         Sustainable Energy for All
# 161    Statistical Capacity Indicators
# 1134              Education Statistics
# 1135              Education Statistics
# 1136              Education Statistics
# 1137              Education Statistics
# 1138              Education Statistics
# 1139              Education Statistics
# 1140              Education Statistics
# 1141              Education Statistics
# 1142              Education Statistics
# 1143              Education Statistics
# 1144              Education Statistics
# 1145              Education Statistics
# 1146              Education Statistics
# 1147              Education Statistics
# 1148              Education Statistics
# 1149              Education Statistics
# 1150              Education Statistics
# 1151              Education Statistics
# 1152              Education Statistics
# 1153              Education Statistics
# 1154              Education Statistics
# 1155              Education Statistics
# 1156              Education Statistics
# ...                                ...
# 16232         Global Social Protection
# 16233         Global Social Protection
# 16234         Global Social Protection
# 16235         Global Social Protection
# 16236         Global Social Protection
# 16237         Global Social Protection
# 16238         Global Social Protection
# 16239         Global Social Protection
# 16240         Global Social Protection
# 16241         Global Social Protection
# 16826         Global Social Protection
# 16827         Global Social Protection
# 16828         Global Social Protection
# 16829         Global Social Protection
# 16830         Global Social Protection
# 16831         Global Social Protection
# 16832         Global Social Protection
# 16833         Global Social Protection
# 16834         Global Social Protection
# 16835         Global Social Protection
# 16836         Global Social Protection
# 16837         Global Social Protection
# 16838         Global Social Protection
# 16839         Global Social Protection
# 16840         Global Social Protection
# 16841         Global Social Protection
# 16842         Global Social Protection
# 16843         Global Social Protection
# 16844         Global Social Protection
# 16845         Global Social Protection
#
#                                               sourceNote  \
# 24     Access to electricity is the percentage of pop...
# 39     Access to electricity is the percentage of rur...
# 40     Access to electricity is the percentage of tot...
# 118    Access to Non-Solid Fuel is the percentage of ...
# 121    Access to Non-Solid Fuel is the percentage of ...
# 123    Access to Non-Solid Fuel is the percentage of ...
# 161    Population censuses collect data on the size, ...
# 1134   Percentage of female population age 15-19 with...
# 1135   Percentage of population age 15-19 with no edu...
# 1136   Percentage of female population age 15+ with n...
# 1137   Percentage of population age 15+ with no educa...
# 1138   Percentage of female population age 20-24 with...
# 1139   Percentage of population age 20-24 with no edu...
# 1140   Percentage of female population age 25-29 with...
# 1141   Percentage of population age 25-29 with no edu...
# 1142   Percentage of female population age 25+ with n...
# 1143   Percentage of population age 25+ with no educa...
# 1144   Percentage of female population age 30-34 with...
# 1145   Percentage of population age 30-34 with no edu...
# 1146   Percentage of female population age 35-39 with...
# 1147   Percentage of population age 35-39 with no edu...
# 1148   Percentage of female population age 40-44 with...
# 1149   Percentage of population age 40-44 with no edu...
# 1150   Percentage of female population age 45-49 with...
# 1151   Percentage of population age 45-49 with no edu...
# 1152   Percentage of female population age 50-54 with...
# 1153   Percentage of population age 50-54 with no edu...
# 1154   Percentage of female population age 55-59 with...
# 1155   Percentage of population age 55-59 with no edu...
# 1156   Percentage of female population age 60-64 with...
# ...                                                  ...
# 16232                                               NULL
# 16233                                               NULL
# 16234                                               NULL
# 16235                                               NULL
# 16236                                               NULL
# 16237                                               NULL
# 16238                                               NULL
# 16239                                               NULL
# 16240                                               NULL
# 16241                                               NULL
# 16826                                               NULL
# 16827                                               NULL
# 16828                                               NULL
# 16829                                               NULL
# 16830                                               NULL
# 16831                                               NULL
# 16832                                               NULL
# 16833                                               NULL
# 16834                                               NULL
# 16835                                               NULL
# 16836                                               NULL
# 16837                                               NULL
# 16838                                               NULL
# 16839                                               NULL
# 16840                                               NULL
# 16841                                               NULL
# 16842                                               NULL
# 16843                                               NULL
# 16844                                               NULL
# 16845                                               NULL
#
#                                       sourceOrganization  \
# 24       World Bank Global Electrification Database 2012
# 39       World Bank Global Electrification Database 2013
# 40       World Bank Global Electrification Database 2014
# 118            WHO Global Household Energy Database 2012
# 121            WHO Global Household Energy Database 2013
# 123            WHO Global Household Energy Database 2014
# 161    World Bank Microdata library. Original source:...
# 1134   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1135   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1136   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1137   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1138   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1139   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1140   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1141   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1142   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1143   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1144   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1145   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1146   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1147   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1148   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1149   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1150   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1151   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1152   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1153   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1154   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1155   Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1156   Robert J. Barro and Jong-Wha Lee: http://www.b...
# ...                                                  ...
# 16232  The Atlas of Social Protection: Indicators of ...
# 16233  The Atlas of Social Protection: Indicators of ...
# 16234  The Atlas of Social Protection: Indicators of ...
# 16235  The Atlas of Social Protection: Indicators of ...
# 16236  The Atlas of Social Protection: Indicators of ...
# 16237  The Atlas of Social Protection: Indicators of ...
# 16238  The Atlas of Social Protection: Indicators of ...
# 16239  The Atlas of Social Protection: Indicators of ...
# 16240  The Atlas of Social Protection: Indicators of ...
# 16241  The Atlas of Social Protection: Indicators of ...
# 16826  The Atlas of Social Protection: Indicators of ...
# 16827  The Atlas of Social Protection: Indicators of ...
# 16828  The Atlas of Social Protection: Indicators of ...
# 16829  The Atlas of Social Protection: Indicators of ...
# 16830  The Atlas of Social Protection: Indicators of ...
# 16831  The Atlas of Social Protection: Indicators of ...
# 16832  The Atlas of Social Protection: Indicators of ...
# 16833  The Atlas of Social Protection: Indicators of ...
# 16834  The Atlas of Social Protection: Indicators of ...
# 16835  The Atlas of Social Protection: Indicators of ...
# 16836  The Atlas of Social Protection: Indicators of ...
# 16837  The Atlas of Social Protection: Indicators of ...
# 16838  The Atlas of Social Protection: Indicators of ...
# 16839  The Atlas of Social Protection: Indicators of ...
# 16840  The Atlas of Social Protection: Indicators of ...
# 16841  The Atlas of Social Protection: Indicators of ...
# 16842  The Atlas of Social Protection: Indicators of ...
# 16843  The Atlas of Social Protection: Indicators of ...
# 16844  The Atlas of Social Protection: Indicators of ...
# 16845  The Atlas of Social Protection: Indicators of ...
#
#                           topics
# 24
# 39
# 40
# 118
# 121
# 123
# 161
# 1134                  Education
# 1135                  Education
# 1136                  Education
# 1137                  Education
# 1138                  Education
# 1139                  Education
# 1140                  Education
# 1141                  Education
# 1142                  Education
# 1143                  Education
# 1144                  Education
# 1145                  Education
# 1146                  Education
# 1147                  Education
# 1148                  Education
# 1149                  Education
# 1150                  Education
# 1151                  Education
# 1152                  Education
# 1153                  Education
# 1154                  Education
# 1155                  Education
# 1156                  Education
# ...                          ...
# 16232  Social Protection & Labor
# 16233  Social Protection & Labor
# 16234  Social Protection & Labor
# 16235  Social Protection & Labor
# 16236  Social Protection & Labor
# 16237  Social Protection & Labor
# 16238  Social Protection & Labor
# 16239  Social Protection & Labor
# 16240  Social Protection & Labor
# 16241  Social Protection & Labor
# 16826  Social Protection & Labor
# 16827  Social Protection & Labor
# 16828  Social Protection & Labor
# 16829  Social Protection & Labor
# 16830  Social Protection & Labor
# 16831  Social Protection & Labor
# 16832  Social Protection & Labor
# 16833  Social Protection & Labor
# 16834  Social Protection & Labor
# 16835  Social Protection & Labor
# 16836  Social Protection & Labor
# 16837  Social Protection & Labor
# 16838  Social Protection & Labor
# 16839  Social Protection & Labor
# 16840  Social Protection & Labor
# 16841  Social Protection & Labor
# 16842  Social Protection & Labor
# 16843  Social Protection & Labor
# 16844  Social Protection & Labor
# 16845  Social Protection & Labor
#
# [1280 rows x 6 columns]

# %%
# Your plotting code
# Plot the combined dataset

# Set map center and zoom level
mapc = [0, 30]
zoom = 2

# Create map object.
map_osm = folium.Map(location=mapc,
                   tiles='Stamen Toner',
                    zoom_start=zoom)

# Plot each of the locations that we geocoded.
for j in range(len(df13)):
    # Plot a blue circle marker for country GDP.
    folium.CircleMarker([df13.lat_mean[j], df13.long_mean[j]],
                    radius=df13.GDP_Worldbank[j],
                    popup='Population',
                    color='green',
                    fill_color='green',
                   ).add_to(map_osm)
    # Plot a red circle marker for students per country.
    folium.CircleMarker([df13.lat_mean[j], df13.long_mean[j]],
                    radius=df13.student_count[j]*100,
                    popup='Students',
                    color='red',
                    fill_color='red',
                   ).add_to(map_osm)
# Show the map.
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
# 
# Add additional cells to break code into units that can be executed should you need to review individual steps.
# Initially wanted to study population 25 + indicator in each country (BAR.NOED.25UP.ZS) and then compare with total student population.
# But the data is not avaliable for many regions so went to GDP indicator

# %% [markdown]
# <br>
# <div class="alert alert-info">
# <b>Exercise 1 End.</b>
# </div>

# %% [markdown]
# > **Exercise complete**:
#
# > This is a good time to "Save and Checkpoint".

# %% [markdown]
# ## 1.2 Wikipedia
#
# To demonstrate how quickly data can be sourced from public, "untrusted" data sources, you have been supplied with a number of sample scripts below. While these sources contain extremely rich datasets that you can acquire with minimal effort, they can be amended by anyone and may not be 100% accurate. In some cases you will have to manually transform the datasets, while in others you might be able to use pre-built libraries.
#
# Execute the code cells below before completing exercise 2.

# %%
#!pip install wikipedia
import wikipedia

# Display page summary
print wikipedia.summary("MIT")
# Out:
# The Massachusetts Institute of Technology (MIT) is a private research university in Cambridge, Massachusetts. Founded in 1861 in response to the increasing industrialization of the United States, MIT adopted a European polytechnic university model and stressed laboratory instruction in applied science and engineering. Researchers worked on computers, radar, and inertial guidance during World War II and the Cold War. Post-war defense research contributed to the rapid expansion of the faculty and campus under James Killian. The current 168-acre (68.0 ha) campus opened in 1916 and extends over 1 mile (1.6 km) along the northern bank of the Charles River basin.
# MIT, with five schools and one college which contain a total of 34 departments, is often cited as among the world's top universities. The Institute is traditionally known for its research and education in the physical sciences and engineering, and more recently in biology, economics, linguistics, and management as well. The "Engineers" sponsor 31 sports, most teams of which compete in the NCAA Division III's New England Women's and Men's Athletic Conference; the Division I rowing programs compete as part of the EARC and EAWRC.
# As of 2015, 85 Nobel laureates, 52 National Medal of Science recipients, 65 Marshall Scholars, 45 Rhodes Scholars, 38 MacArthur Fellows, 34 astronauts, 19 Turing award winners, and 6 Fields Medalists have been affiliated with MIT. The school has a strong entrepreneurial culture, and the aggregated revenues of companies founded by MIT alumni would rank as the eleventh-largest economy in the world.

# %%
# Display a single sentence summary.
wikipedia.summary("MIT", sentences=1)
# Out:
# u'The Massachusetts Institute of Technology (MIT) is a private research university in Cambridge, Massachusetts.'

# %%
# Create variable page that contains the wikipedia information.
page = wikipedia.page("List of countries and dependencies by population")

# Display the page title.
page.title
# Out:
# u'List of countries and dependencies by population'

# %%
# Display the page URL. This can be utilised to create links back to descriptions.
page.url
# Out:
# u'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population'

# %% [markdown]
# <br>
# <div class="alert alert-info">
# <b>Exercise 2 Start.</b>
# </div>
#
# ### Instructions
#
# > After executing the cells for the Wikipedia example in section 1.2, think about the potential implications of using this "public" and in many cases "untrusted" data sources when doing analysis or creating data products.
#
# > **Please compile and submit a short list of pros and cons (three each). Your submission will be evaluated.**
#
# > Your submission can be a simple markdown list or you can use the table syntax provided below.

# %% [markdown]
# Add your answer in this markdown cell. The contents of this cell should be replaced with your answer.
#
# **Submit as a list:**
#
# ListType
# - Pro: Description 1
# - Pro: Description 2
# - Pro: Description 3
# - Con: Description 1
# - Con: Description 2
# - Con: Description 3
#
# **or as a table.**
#
# | Type | Description |
# | ---- | ----------- |
# | Pro | Only be used as a inference |
# | Pro | Maybe used as what would they like but very little weightage needs to be given |
# | Con | Cannot be used as fact |
# | Con | Data from Unverified sources |

# %% [markdown]
# <br>
# <div class="alert alert-info">
# <b>Exercise 2 End.</b>
# </div>

# %% [markdown]
# > **Exercise complete**:
#
# > This is a good time to "Save and Checkpoint".

# %% [markdown]
# ## 2. Submit your notebook
#
# Please make sure that you:
# - Perform a final "Save and Checkpoint";
# - Download a copy of the notebook in ".ipynb" format to your local machine using "File", "Download as", and "IPython Notebook (.ipynb)"; and
# - Submit a copy of this file to the online campus.
